# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nutrition-dataset/nutrition.xlsx

# %%
import pandas as pd
df=pd.read_excel("/kaggle/input/nutrition-dataset/nutrition.xlsx")
df.head(2)
   # df = pd.read_excel('your_file_name.xlsx')
# Out:
#    Unnamed: 0          name serving_size  calories total_fat saturated_fat  \
# 0           0    Cornstarch        100 g       381      0.1g           NaN
# 1           1  Nuts, pecans        100 g       691       72g          6.2g
#
#   cholesterol   sodium  choline     folate  ...      fat  \
# 0           0  9.00 mg   0.4 mg   0.00 mcg  ...   0.05 g
# 1           0  0.00 mg  40.5 mg  22.00 mcg  ...  71.97 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 0                     0.025 g                 0.00 mg   0.0 g  0.09 g
# 1                    21.614 g                 0.00 mg   0.0 g  1.49 g
#
#   caffeine theobromine   water
# 0  0.00 mg     0.00 mg  8.32 g
# 1  0.00 mg     0.00 mg  3.52 g
#
# [2 rows x 77 columns]

# %%
df["saturated_fat"].describe()
# df["saturated_fat"]

# df[df["saturated_fat"]==0.1g]
# Out:
# count     7199
# unique     156
# top       0.1g
# freq       609
# Name: saturated_fat, dtype: object

# %%
df['saturated_fat'] = df['saturated_fat'].str.extract(r'(\d+\.?\d*)').astype(float)
# df["saturated_fat"]

df.fillna(0,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 77 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   8789 non-null   int64
#  1   name                         8789 non-null   object
#  2   serving_size                 8789 non-null   object
#  3   calories                     8789 non-null   int64
#  4   total_fat                    8789 non-null   object
#  5   saturated_fat                8789 non-null   float64
#  6   cholesterol                  8789 non-null   object
#  7   sodium                       8789 non-null   object
#  8   choline                      8789 non-null   object
#  9   folate                       8789 non-null   object
#  10  folic_acid                   8789 non-null   object
#  11  niacin                       8789 non-null   object
#  12  pantothenic_acid             8789 non-null   object
# ...

# %%
df["saturated_fat"].fillna(0,inplace=True)
df
df.drop(columns=['Unnamed: 0'], inplace=True)
# Out:
# /tmp/ipykernel_13/3520253878.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["saturated_fat"].fillna(0,inplace=True)

# %%
df

object_columns = df.select_dtypes(include=['object']).columns.tolist()
object_columns


object_columns

del object_columns[0]

object_columns

# for i in object_columns:
#     df[i] = (
#     df[i]
#     .str.extract(r'(\d+\.?\d*)', expand=False)  # Matches numbers (e.g., 0.9, 123)
#     .astype(float)                             # Convert to float
# )

df
# Out:
#                                                    name serving_size  \
# 0                                            Cornstarch        100 g
# 1                                          Nuts, pecans        100 g
# 2                                         Eggplant, raw        100 g
# 3                                        Teff, uncooked        100 g
# 4                                       Sherbet, orange        100 g
# ...                                                 ...          ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8785  Lamb, cooked, separable lean only, composite o...        100 g
# 8786  Lamb, raw, separable lean and fat, composite o...        100 g
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
#
#       calories total_fat  saturated_fat cholesterol    sodium  choline  \
# ...

# %%
# df.info()

def clean_value(x):
    if isinstance(x, str):
        return x.replace('mg', '').replace('g', '').replace('mcg', '').replace('mc', '').strip()
    return x

object_columns

for i in object_columns:
    df[i]= df[i].apply(clean_value)


df

for col in object_columns:
    df[col] = pd.to_numeric(df[col], errors='ignore')

df.info()
# Out:
# /tmp/ipykernel_13/1263919811.py:17: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_numeric(df[col], errors='ignore')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 76 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         8789 non-null   object
#  1   serving_size                 8789 non-null   int64
#  2   calories                     8789 non-null   int64
#  3   total_fat                    8789 non-null   float64
#  4   saturated_fat                8789 non-null   float64
#  5   cholesterol                  8789 non-null   int64
#  6   sodium                       8789 non-null   float64
#  7   choline                      8789 non-null   float64
# ...

# %%
len(df["vitamin_a"].unique())

df["vitamin_a"].unique()
# Out:
# array(['0.00 IU', '56.00 IU', '23.00 IU', ..., '504.00 IU', '2090.00 IU',
#        '4286.00 IU'], dtype=object)

# %%
def clean_value(x):
    if isinstance(x, str):
        return x.replace('mg', '').replace('g', '').replace('mcg', '').replace('mc', '').replace('IU', '').strip()
    return x

df["vitamin_a"]=df["vitamin_a"].apply(clean_value)

df["vitamin_a"]

df["vitamin_a"] = pd.to_numeric(df["vitamin_a"], errors='ignore')

type(df["vitamin_a"])

df["vitamin_a"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8789 entries, 0 to 8788
# Series name: vitamin_a
# Non-Null Count  Dtype
# --------------  -----
# 8789 non-null   float64
# dtypes: float64(1)
# memory usage: 68.8 KB
# /tmp/ipykernel_13/1469552010.py:10: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df["vitamin_a"] = pd.to_numeric(df["vitamin_a"], errors='ignore')

# %%
df["vitamin_d"]
# Out:
# 0       0.00 IU
# 1       0.00 IU
# 2       0.00 IU
# 3             0
# 4       0.00 IU
#          ...
# 8784    1.00 IU
# 8785          0
# 8786          0
# 8787    1.00 IU
# 8788    1.00 IU
# Name: vitamin_d, Length: 8789, dtype: object

# %%
def clean_value(x):
    if isinstance(x, str):
        return x.replace('mg', '').replace('g', '').replace('mcg', '').replace('mc', '').replace('IU', '').strip()
    return x

df["vitamin_d"]=df["vitamin_d"].apply(clean_value)

df["vitamin_d"]=pd.to_numeric(df["vitamin_d"],errors='ignore')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 76 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         8789 non-null   object
#  1   serving_size                 8789 non-null   int64
#  2   calories                     8789 non-null   int64
#  3   total_fat                    8789 non-null   float64
#  4   saturated_fat                8789 non-null   float64
#  5   cholesterol                  8789 non-null   int64
#  6   sodium                       8789 non-null   float64
#  7   choline                      8789 non-null   float64
#  8   folate                       8789 non-null   float64
#  9   folic_acid                   8789 non-null   float64
#  10  niacin                       8789 non-null   float64
#  11  pantothenic_acid             8789 non-null   float64
# ...

# %%
df["folic_acid"].info()

len(df[df["folic_acid"]!=0]["folic_acid"])
df[df["folic_acid"]!=0]["folic_acid"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8789 entries, 0 to 8788
# Series name: folic_acid
# Non-Null Count  Dtype
# --------------  -----
# 8789 non-null   float64
# dtypes: float64(1)
# memory usage: 68.8 KB
# <class 'pandas.core.series.Series'>
# Index: 1183 entries, 13 to 8771
# Series name: folic_acid
# Non-Null Count  Dtype
# --------------  -----
# 1183 non-null   float64
# dtypes: float64(1)
# memory usage: 18.5 KB

# %%
df[df["folic_acid"]!=0]["folic_acid"].describe()
df[df["folic_acid"]==2993.000000]
# Out:
#                      name  serving_size  calories  total_fat  saturated_fat  \
# 132  Yeast extract spread           100       185        0.9            0.0
#
#      cholesterol  sodium  choline  folate  folic_acid  ...  fat  \
# 132            0  3380.0     65.1  3786.0      2993.0  ...  0.9
#
#      saturated_fatty_acids  monounsaturated_fatty_acids  \
# 132                    0.0                          0.0
#
#      polyunsaturated_fatty_acids  fatty_acids_total_trans  alcohol   ash  \
# 132                          0.0                      0.0      0.0  13.9
#
#      caffeine  theobromine  water
# 132       0.0          0.0   40.9
#
# [1 rows x 76 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 76 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         8789 non-null   object
#  1   serving_size                 8789 non-null   int64
#  2   calories                     8789 non-null   int64
#  3   total_fat                    8789 non-null   float64
#  4   saturated_fat                8789 non-null   float64
#  5   cholesterol                  8789 non-null   int64
#  6   sodium                       8789 non-null   float64
#  7   choline                      8789 non-null   float64
#  8   folate                       8789 non-null   float64
#  9   folic_acid                   8789 non-null   float64
#  10  niacin                       8789 non-null   float64
#  11  pantothenic_acid             8789 non-null   float64
# ...

# %%
df
# Out:
#                                                    name  serving_size  \
# 0                                            Cornstarch           100
# 1                                          Nuts, pecans           100
# 2                                         Eggplant, raw           100
# 3                                        Teff, uncooked           100
# 4                                       Sherbet, orange           100
# ...                                                 ...           ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...           100
# 8785  Lamb, cooked, separable lean only, composite o...           100
# 8786  Lamb, raw, separable lean and fat, composite o...           100
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...           100
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...           100
#
#       calories  total_fat  saturated_fat  cholesterol  sodium  choline  \
# ...

# %%
df.iloc[8787]
# Out:
# name             Beef, raw, all grades, trimmed to 0" fat, sepa...
# serving_size                                                   100
# calories                                                       121
# total_fat                                                      3.0
# saturated_fat                                                  1.1
#                                        ...
# alcohol                                                        0.0
# ash                                                            1.1
# caffeine                                                       0.0
# theobromine                                                    0.0
# water                                                        73.43
# Name: 8787, Length: 76, dtype: object

# %%
df.select_dtypes('float')
# Out:
#       total_fat  saturated_fat  sodium  choline  folate  folic_acid  niacin  \
# 0           0.1            0.0     9.0      0.4     0.0         0.0   0.000
# 1          72.0            6.2     0.0     40.5    22.0         0.0   1.167
# 2           0.2            0.0     2.0      6.9    22.0         0.0   0.649
# 3           2.4            0.4    12.0     13.1     0.0         0.0   3.363
# 4           2.0            1.2    46.0      7.7     4.0         0.0   0.063
# ...         ...            ...     ...      ...     ...         ...     ...
# 8784        3.5            1.4    54.0     64.5     4.0         0.0   6.422
# 8785        8.9            3.9    50.0      0.0     0.0         0.0   7.680
# 8786       23.0           12.0    39.0      0.0     1.0         0.0   6.550
# 8787        3.0            1.1    53.0     64.2     4.0         0.0   6.720
# 8788        3.0            1.1    53.0     64.2     4.0         0.0   6.720
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 76 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         8789 non-null   object
#  1   serving_size                 8789 non-null   int64
#  2   calories                     8789 non-null   int64
#  3   total_fat                    8789 non-null   float64
#  4   saturated_fat                8789 non-null   float64
#  5   cholesterol                  8789 non-null   int64
#  6   sodium                       8789 non-null   float64
#  7   choline                      8789 non-null   float64
#  8   folate                       8789 non-null   float64
#  9   folic_acid                   8789 non-null   float64
#  10  niacin                       8789 non-null   float64
#  11  pantothenic_acid             8789 non-null   float64
# ...

# %%
df["score"]=(1-df.get("sodium",0)) + (1-df.get('caffeine',0))
df
# Out:
#                                                    name  serving_size  \
# 0                                            Cornstarch           100
# 1                                          Nuts, pecans           100
# 2                                         Eggplant, raw           100
# 3                                        Teff, uncooked           100
# 4                                       Sherbet, orange           100
# ...                                                 ...           ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...           100
# 8785  Lamb, cooked, separable lean only, composite o...           100
# 8786  Lamb, raw, separable lean and fat, composite o...           100
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...           100
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...           100
#
#       calories  total_fat  saturated_fat  cholesterol  sodium  choline  \
# ...

# %%
# df["score"]=(1-df.get("sodium",0)) + (1-df.get('caffeine',0))
# df

df["score"]=(1-df.get("water",0))
df["score"]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 77 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         8789 non-null   object
#  1   serving_size                 8789 non-null   int64
#  2   calories                     8789 non-null   int64
#  3   total_fat                    8789 non-null   float64
#  4   saturated_fat                8789 non-null   float64
#  5   cholesterol                  8789 non-null   int64
#  6   sodium                       8789 non-null   float64
#  7   choline                      8789 non-null   float64
#  8   folate                       8789 non-null   float64
#  9   folic_acid                   8789 non-null   float64
#  10  niacin                       8789 non-null   float64
#  11  pantothenic_acid             8789 non-null   float64
# ...

# %%
def food_for_condition(df,cond,top_n=10):
    df=df.copy()
    if cond=="Obesity": # 🔽 Calories<br>🔽 Saturated fats & added sugars<br>🔼 Fiber<br>🔼 Protein (moderate)<br>⚖️ Balanced carbs 
        df["score"]=(1-df["calories"]) + (1-df["saturated_fatty_acids"]) +(1-df["sugars"]) +df["fiber"] + df["protein"]
    elif cond=="Diabetes": #🔽 Simple sugars & refined carbs<br>🔽 Saturated fats<br>🔼 Fiber<br>⚖️ Complex carbs<br>🔼 Lean protein
        df["score"]=(1-df["saturated_fat"]) + (1-df["sugers"]) +(1-df["carbohydrate"]) +df["fiber"] + df["protein"]
    elif cond=="High Cholesterol (Hyperlipidemia)":
        #🔽 Saturated fats & trans fats<br>🔼 Fiber (especially soluble fiber)<br>🔼 Omega-3 fats<br>⚖️ Protein 
        df["score"]=(1-df["saturated_fat"]) + (1-df["sugers"]) +(1-df["carbohydrate"]) +df["fiber"] + df["protein"]
    elif cond=="Hypertension (High Blood Pressure)": #🔽 Sodium<br>🔼 Potassium<br>🔼 Magnesium<br>🔼 Calcium<br>🔼 Fiber<br>🔽 Saturated fats
        df["score"]=(1-df["saturated_fat"]) + (1-df["sodium"]) +(1-df["calcium"]) +df["fiber"] + 1-df["potassium"] +(1-df["magnesium"])
        #🔽 Saturated & trans fats<br>🔼 Fiber<br>🔼 Omega-3 fats<br>🔼 Potassium & antioxidants 
    elif cond=="Heart Disease":
        df["score"]=(1-df["saturated_fat"])+ df["fiber"] + df["potassium"]
    elif cond=="Fatty Liver": #🔽 Fructose (especially sugary drinks)<br>🔽 Saturated fats<br>🔼 Fiber<br>🔼 Lean protein
        df["score"]=1-df["fructose"]+(1-df["saturated_fat"])+df["fiber"] + df["protein"]
    elif cond=="Stroke": #🔽 Sodium<br>🔽 Saturated fats<br>🔼 Fiber<br>🔼 Potassium<br>🔼 Antioxidants (Vitamin C, E)
        df["score"]= (1-df["sodium"]) + (1-df["saturated_fat"]) + df["fiber"] + df["potassium"] + df["vitamin_c"]+ df["vitamin_e"]
    elif cond=="Kidney Disease":
        df["score"] = (1 - df["sodium"]) + (1 - df["phosphorous"]) + (1 - df["potassium"]) + (1 - df["protein"]) + df["fiber"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 77 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         8789 non-null   object
#  1   serving_size                 8789 non-null   int64
#  2   calories                     8789 non-null   int64
#  3   total_fat                    8789 non-null   float64
#  4   saturated_fat                8789 non-null   float64
#  5   cholesterol                  8789 non-null   int64
#  6   sodium                       8789 non-null   float64
#  7   choline                      8789 non-null   float64
#  8   folate                       8789 non-null   float64
#  9   folic_acid                   8789 non-null   float64
#  10  niacin                       8789 non-null   float64
#  11  pantothenic_acid             8789 non-null   float64
# ...

# %%
# | Disease / Condition                           | Nutrient Focus                                                                                                                 |
# | --------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------ |
# | **Obesity**                                   | 🔽 Calories<br>🔽 Saturated fats & added sugars<br>🔼 Fiber<br>🔼 Protein (moderate)<br>⚖️ Balanced carbs                      |
# | **Type 2 Diabetes**                           | 🔽 Simple sugars & refined carbs<br>🔽 Saturated fats<br>🔼 Fiber<br>⚖️ Complex carbs<br>🔼 Lean protein                       |
# | **High Cholesterol (Hyperlipidemia)**         | 🔽 Saturated fats & trans fats<br>🔼 Fiber (especially soluble fiber)<br>🔼 Omega-3 fats<br>⚖️ Protein                         |
# | **Hypertension (High Blood Pressure)**        | 🔽 Sodium<br>🔼 Potassium<br>🔼 Magnesium<br>🔼 Calcium<br>🔼 Fiber<br>🔽 Saturated fats                                       |
# | **Non-Alcoholic Fatty Liver Disease (NAFLD)** | 🔽 Fructose (especially sugary drinks)<br>🔽 Saturated fats<br>🔼 Fiber<br>🔼 Lean protein                                     |
# | **Coronary Artery Disease (Heart Disease)**   | 🔽 Saturated & trans fats<br>🔼 Fiber<br>🔼 Omega-3 fats<br>🔼 Potassium & antioxidants                                        |
# | **Stroke**                                    | 🔽 Sodium<br>🔽 Saturated fats<br>🔼 Fiber<br>🔼 Potassium<br>🔼 Antioxidants (Vitamin C, E)                                   |
# | **Metabolic Syndrome**                        | 🔽 Refined carbs, sugars<br>🔽 Saturated fats<br>🔼 Fiber<br>🔼 Lean protein<br>⚖️ Healthy fats                                |
# | **Chronic Kidney Disease (Early stage)**      | 🔽 Sodium<br>🔽 Phosphorus<br>🔽 Potassium (stage-dependent)<br>⚖️ Controlled protein<br>🔽 Processed food additives           |
# | **Gastroesophageal Reflux Disease (GERD)**    | 🔽 Fatty foods<br>🔽 Caffeine<br>🔽 Acidic foods<br>⚖️ Small balanced meals                                                    |
# | **Fatty Liver (Alcoholic / Non-Alcoholic)**   | 🔽 Alcohol<br>🔽 Added sugars<br>🔽 Saturated fats<br>🔼 Fiber<br>🔼 Protein (moderate, lean)                                  |
# | **Gout**                                      | 🔽 Purines (found in red meat, organ meats, seafood)<br>🔼 Water<br>🔼 Low-fat dairy<br>🔽 Alcohol                             |
# | **Osteoporosis**                              | 🔼 Calcium<br>🔼 Vitamin D<br>🔼 Magnesium<br>🔼 Protein (adequate, not excessive)<br>🔼 Vitamin K                             |
# | **PCOS (Polycystic Ovary Syndrome)**          | 🔽 Refined carbs<br>🔼 Fiber<br>🔼 Lean protein<br>🔽 Saturated fats<br>⚖️ Balanced fats                                       |
# | **Sleep Apnea (indirectly through obesity)**  | Follow obesity guidelines → 🔽 Calories, 🔼 Fiber, 🔼 Lean protein                                                             |
# | **Fatigue / Chronic Fatigue Syndrome**        | 🔼 Iron (if deficient)<br>🔼 B vitamins<br>🔼 Complex carbs<br>🔼 Fluids<br>⚖️ Balanced protein & carbs                        |
# | **Depression & Anxiety (diet supportive)**    | 🔼 Omega-3 fats<br>🔼 Magnesium<br>🔼 Vitamin B12, folate<br>🔼 Antioxidants<br>⚖️ Stable blood sugar (balanced carbs/protein) |

# %%
def food_for_condition(df, cond, top_n=10):
    df = df.copy()

    if cond == "Obesity":
        df["score"] = (1 - df["calories"]) + (1 - df["saturated_fatty_acids"]) + (1 - df["sugars"]) + df["fiber"] + df["protein"]

    elif cond == "Type 2 Diabetes":
        df["score"] = (1 - df["sugars"]) + (1 - df["carbohydrate"]) + (1 - df["saturated_fat"]) + df["fiber"] + df["protein"]

    elif cond == "High Cholesterol (Hyperlipidemia)":
        df["score"] = (1 - df["saturated_fat"]) + (1 - df["fatty_acids_total_trans"]) + df["fiber"] + df["protein"]

    elif cond == "Hypertension (High Blood Pressure)":
        df["score"] = (1 - df["sodium"]) + (1 - df["saturated_fat"]) + df["potassium"] + df["magnesium"] + df["calcium"] + df["fiber"]

    elif cond == "Non-Alcoholic Fatty Liver Disease (NAFLD)":
        df["score"] = (1 - df["fructose"]) + (1 - df["saturated_fat"]) + df["fiber"] + df["protein"]

    elif cond == "Coronary Artery Disease (Heart Disease)":
        df["score"] = (1 - df["saturated_fat"]) + (1 - df["fatty_acids_total_trans"]) + df["fiber"] + df["potassium"] + df["vitamin_c"] + df["vitamin_e"]

    elif cond == "Stroke":
        df["score"] = (1 - df["sodium"]) + (1 - df["saturated_fat"]) + df["fiber"] + df["potassium"] + df["vitamin_c"] + df["vitamin_e"]

    elif cond == "Metabolic Syndrome":
        df["score"] = (1 - df["sugars"]) + (1 - df["carbohydrate"]) + (1 - df["saturated_fat"]) + df["fiber"] + df["protein"]

    elif cond == "Chronic Kidney Disease (Early stage)":
        df["score"] = (1 - df["sodium"]) + (1 - df["phosphorous"]) + (1 - df["potassium"]) + (1 - df["protein"]) + df["fiber"]

    elif cond == "Gastroesophageal Reflux Disease (GERD)":
        df["score"] = (1 - df["saturated_fat"]) + (1 - df["caffeine"]) + df["fiber"]

    elif cond == "Fatty Liver (Alcoholic / Non-Alcoholic)":
        df["score"] = (1 - df["alcohol"]) + (1 - df["sugars"]) + (1 - df["saturated_fat"]) + df["fiber"] + df["protein"]

    elif cond == "Gout":
        df["score"] = (1 - df["protein"]) + df["water"] + df["fiber"]  # Purines not in your df, so protein used as proxy

    elif cond == "Osteoporosis":
        df["score"] = df["calcium"] + df["vitamin_d"] + df["magnesium"] + df["vitamin_k"] + df["protein"]

    elif cond == "PCOS (Polycystic Ovary Syndrome)":
        df["score"] = (1 - df["carbohydrate"]) + (1 - df["saturated_fat"]) + df["fiber"] + df["protein"]

    elif cond == "Sleep Apnea":
        df["score"] = (1 - df["calories"]) + df["fiber"] + df["protein"]

    elif cond == "Fatigue / Chronic Fatigue Syndrome":
        df["score"] = df["irom"] + df["vitamin_b12"] + df["thiamin"] + df["carbohydrate"] + df["water"] + df["protein"]

    elif cond == "Depression & Anxiety":
        df["score"] = df["vitamin_b12"] + df["folate"] + df["vitamin_c"] + df["vitamin_e"] + df["magnesium"] + df["protein"]

    else:
        raise ValueError(f"Condition '{cond}' not recognized.")

    return df.sort_values("score", ascending=False)[["name", "score"]].head(top_n)

# %%
food_for_condition(df,"Fatty Liver (Alcoholic / Non-Alcoholic)",10)["name"].iloc[:4]
# Out:
# 1378    Soy protein isolate, potassium type
# 213                     Soy protein isolate
# 404                        Corn bran, crude
# 1618      Gelatins, unsweetened, dry powder
# Name: name, dtype: object

# %%
import random

def meal_plan(df, target_calories, meals):
    df = df.copy()
    plan = []
    total_cal = 0

    for _ in range(meals * 10):  # Try multiple times
        sample = df.sample(meals)
        cal = sample['calories'].sum()

        if abs(cal - target_calories) <= 300:
            plan = sample
            total_cal = cal
            break

    if len(plan) == 0:
        return f"😢 No combination is found {target_calories}±100 Calories"

    return plan[['name', 'calories', 'protein', 'carbohydrate', 'fat']]

# %%
meal_plan(df, target_calories=1000, meals=3)
# Out:
#                                                    name  calories  protein  \
# 5924  Cereals ready-to-eat, KELLOGG'S SPECIAL K Blue...       363     6.90
# 8215  Beef, roasted, cooked, all grades, trimmed to ...       183    26.65
# 1693                   T.G.I. FRIDAY'S, chicken fingers       325    18.68
#
#       carbohydrate    fat
# 5924         86.30   1.50
# 8215          0.00   8.46
# 1693         16.84  20.31

# %%
xxx=pd.read_excel("/kaggle/input/nutrition-dataset/nutrition.xlsx")
object_d=df.select_dtypes(include=['number']).columns.tolist()
object_d

# del object_d[0]

object_d
# Out:
# ['serving_size',
#  'calories',
#  'total_fat',
#  'saturated_fat',
#  'cholesterol',
#  'sodium',
#  'choline',
#  'folate',
#  'folic_acid',
#  'niacin',
#  'pantothenic_acid',
#  'riboflavin',
#  'thiamin',
#  'vitamin_a',
#  'vitamin_a_rae',
#  'carotene_alpha',
#  'carotene_beta',
#  'cryptoxanthin_beta',
#  'lutein_zeaxanthin',
#  'lucopene',
#  'vitamin_b12',
#  'vitamin_b6',
#  'vitamin_c',
#  'vitamin_d',
#  'vitamin_e',
#  'tocopherol_alpha',
#  'vitamin_k',
#  'calcium',
#  'copper',
#  'irom',
#  'magnesium',
#  'manganese',
#  'phosphorous',
#  'potassium',
#  'selenium',
#  'zink',
#  'protein',
#  'alanine',
#  'arginine',
#  'aspartic_acid',
#  'cystine',
#  'glutamic_acid',
#  'glycine',
#  'histidine',
#  'hydroxyproline',
#  'isoleucine',
#  'leucine',
#  'lysine',
#  'methionine',
#  'phenylalanine',
#  'proline',
#  'serine',
#  'threonine',
#  'tryptophan',
#  'tyrosine',
#  'valine',
#  'carbohydrate',
#  'fiber',
#  'sugars',
#  'fructose',
#  'galactose',
# ...

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
nutrient_cols=object_d
X = df[nutrient_cols]

kmeans = KMeans(n_clusters=6)
df['cluster'] = kmeans.fit_predict(X)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df[df["cluster"]==1]
# Out:
#                                                    name  serving_size  \
# 109                               Parsley, freeze-dried           100
# 153                                Chives, freeze-dried           100
# 256                                 Fish oil, cod liver           100
# 304                                  Carrot, dehydrated           100
# 1417                 Walrus, raw (Alaska Native), liver           100
# 1607                  Peppers, freeze-dried, red, sweet           100
# 2416              Moose, braised (Alaska Native), liver           100
# 5783  Veal, pan-fried, cooked, liver, variety meats ...           100
# 5875  Lamb, soaked and fried, cooked, liver, importe...           100
# 6036  Veal, braised, cooked, liver, variety meats an...           100
# 6220  Beef, raw, liver, variety meats and by-product...           100
# 7002  Beef, boiled, cooked, variety meats and by-pro...           100
#
# ...

# %%
Old_df=df.copy()
Old_df.head(1)
# Out:
#          name  serving_size  calories  total_fat  saturated_fat  cholesterol  \
# 0  Cornstarch           100       381        0.1            0.0            0
#
#    sodium  choline  folate  folic_acid  ...  monounsaturated_fatty_acids  \
# 0     9.0      0.4     0.0         0.0  ...                        0.016
#
#    polyunsaturated_fatty_acids  fatty_acids_total_trans  alcohol   ash  \
# 0                        0.025                      0.0      0.0  0.09
#
#    caffeine  theobromine  water  score  cluster
# 0       0.0          0.0   8.32  -7.32        0
#
# [1 rows x 78 columns]

# %%
# import streamlit as st
# import pandas as pd
# import random

# # -------------------------------
# # Helper Functions
# # -------------------------------

# @st.cache_data
# def load_data():
#     # df = pd.read_excel("/kaggle/input/nutrition-dataset/nutrition.xlsx")
#     df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
#     df.rename(columns={df.columns[0]: 'name'}, inplace=True)
#     # Fill missing
#     for col in df.columns:
#         if col != 'name':
#             df[col] = df[col].fillna(df[col].mean())
#     return df

# def scale_nutrients(row, amount_g):
#     scaled = {'name': row['name'], 'amount_g': amount_g}
#     for col in row.index:
#         if col != 'name':
#             scaled[col] = (row[col] * amount_g) / 100
#     return scaled

# def recommend_food_for_condition(df, condition, top_n=10):
#     df = df.copy()
#     if condition == 'diabetes':
#         df['score'] = (1 - df.get('sugar', 0)) + (1 - df.get('carbohydrate', 0)) + df.get('fiber', 0)
#     elif condition == 'kidney':
#         df['score'] = (1 - df.get('sodium', 0)) + (1 - df.get('potassium', 0)) + (1 - df.get('phosphorus', 0))
#     elif condition == 'obesity':
#         df['score'] = (1 - df['calories']) + (1 - df['fat']) + df.get('fiber', 0)
#     else:
#         df['score'] = 0
#     return df.sort_values('score', ascending=False)[['name', 'score']].head(top_n)

# def meal_plan_realistic(df, target_calories=1800, meals=3):
#     df = df.copy()
#     meal = []
#     for _ in range(meals * 10):
#         samples = df.sample(meals)
#         total_cal = 0
#         temp_plan = []
#         for _, row in samples.iterrows():
#             amt = random.randint(30, 150)
#             scaled = scale_nutrients(row, amt)
#             total_cal += scaled.get('calories', 0)
#             temp_plan.append(scaled)
#         if abs(total_cal - target_calories) <= 150:
#             meal = temp_plan
#             break
#     if not meal:
#         return "😢 Sorry, No matching meal found"
#     return pd.DataFrame(meal)

# # -------------------------------
# # Streamlit UI
# # -------------------------------

# df = load_data()

# st.title("🍽️ SmartNutriPlan - AI Meal & Food Recommender")

# st.header("🔍 Disease Based Food Recommendation")
# condition = st.selectbox("Select a health condition", ["diabetes", "kidney", "obesity"])
# food_suggestion = recommend_food_for_condition(df, condition)
# st.write(food_suggestion)

# st.header("🥗 Meal Plan Generator")
# target_cal = st.number_input("Enter your daily calorie target", min_value=500, max_value=5000, value=2000, step=50)
# meals = st.slider("Number of meals", 1, 5, 3)
# if st.button("Generate Meal Plan"):
#     meal = meal_plan_realistic(df, target_calories=target_cal, meals=meals)
#     st.write(meal[['name', 'amount_g', 'calories', 'protein', 'fat', 'carbohydrate']])

# %%
# !pip install streamlit

# %%
nutrition_summary = df.groupby('name').agg({
    'calories': 'mean',        # প্রতিটি খাবারের গড় ক্যালরি
    'protein': 'mean',         # প্রতিটি খাবারের গড় প্রোটিন
    'carbohydrate': 'mean',    # প্রতিটি খাবারের গড় কার্বোহাইড্রেট
    'fat': 'mean',             # প্রতিটি খাবারের গড় ফ্যাট
    'fiber': 'mean'            # প্রতিটি খাবারের গড় ফাইবার
}).sort_values('calories', ascending=False)  # ক্যালরি অনুসারে সাজানো (উচ্চ থেকে নিম্ন)

print(nutrition_summary.head())  # প্রথম ৫টি ফলাফল দেখাবে
# Out:
#                                         calories  protein  carbohydrate  \
# name
# Lard                                       902.0      0.0           0.0
# Fish oil, sardine                          902.0      0.0           0.0
# Fat, mutton tallow                         902.0      0.0           0.0
# Fish oil, fully hydrogenated, menhaden     902.0      0.0           0.0
# Fat, beef tallow                           902.0      0.0           0.0
#
#                                           fat  fiber
# name
# Lard                                    100.0    0.0
# Fish oil, sardine                       100.0    0.0
# Fat, mutton tallow                      100.0    0.0
# Fish oil, fully hydrogenated, menhaden  100.0    0.0
# Fat, beef tallow                        100.0    0.0

# %%
vitamin_sources = df.groupby('name').agg({
    'vitamin_a': 'max',  # ভিটামিন-এ এর সর্বোচ্চ মান
    'vitamin_c': 'max',  # ভিটামিন-সি এর সর্বোচ্চ মান
    'vitamin_d': 'max',  # ভিটামিন-ডি এর সর্বোচ্চ মান
    'vitamin_e': 'max'   # ভিটামিন-ই এর সর্বোচ্চ মান
}).sort_values('vitamin_c', ascending=False)  # ভিটামিন-সি অনুসারে সাজানো

print(vitamin_sources.head())
# Out:
#                                                     vitamin_a  vitamin_c  \
# name
# Babyfood, organic, carrot and squash, apple, 2n...      417.0     2732.0
# Beverages, powder, low calorie, breakfast type,...    20000.0     2400.0
# Beverages, low calorie, with high vitamin C wit...    20000.0     2400.0
# Peppers, freeze-dried, red, sweet                     77261.0     1900.0
# Peppers, freeze-dried, green, sweet                    5640.0     1900.0
#
#                                                     vitamin_d  vitamin_e
# name
# Babyfood, organic, carrot and squash, apple, 2n...        0.0       0.07
# Beverages, powder, low calorie, breakfast type,...        0.0       0.00
# Beverages, low calorie, with high vitamin C wit...        0.0       0.02
# Peppers, freeze-dried, red, sweet                         0.0       4.00
# Peppers, freeze-dried, green, sweet                       0.0       4.00

# %%
mineral_rich = df.groupby('name').agg({
    'calcium': 'max',      # সর্বোচ্চ ক্যালসিয়াম
    'sodium': 'max',         # সর্বোচ্চ আয়রন (আপনার ডাটায় 'irom' লেখা আছে, সঠিক করুন)
    'potassium': 'max',    # সর্বোচ্চ পটাশিয়াম
    'magnesium': 'max'     # সর্বোচ্চ ম্যাগনেসিয়াম
}).sort_values('potassium', ascending=False)  # পটাশিয়াম অনুসারে সাজানো

print(mineral_rich.head())
# Out:
#                                                     calcium  sodium  \
# name
# Leavening agents, cream of tartar                       8.0    52.0
# Leavening agents, low-sodium, baking powder          4332.0    90.0
# Parsley, freeze-dried                                 176.0   391.0
# Beverages, powder, unsweetened, instant, tea          118.0    72.0
# Beverages, unsweetened, decaffeinated, instant,...    118.0    72.0
#
#                                                     potassium  magnesium
# name
# Leavening agents, cream of tartar                     16500.0        2.0
# Leavening agents, low-sodium, baking powder           10100.0       29.0
# Parsley, freeze-dried                                  6300.0      372.0
# Beverages, powder, unsweetened, instant, tea           6040.0      272.0
# Beverages, unsweetened, decaffeinated, instant,...     6040.0      272.0

# %%
fat_analysis = df.groupby('name').agg({
    'total_fat': 'mean',                      # গড় টোটাল ফ্যাট
    'saturated_fat': 'mean',                  # গড় স্যাচুরেটেড ফ্যাট
    'monounsaturated_fatty_acids': 'mean',    # গড় মনোআনস্যাচুরেটেড ফ্যাট
    'polyunsaturated_fatty_acids': 'mean'     # গড় পলিআনস্যাচুরেটেড ফ্যাট
}).sort_values('total_fat', ascending=False)  # টোটাল ফ্যাট অনুসারে সাজানো

print(fat_analysis.head())
# Out:
#                                                  total_fat  saturated_fat  \
# name
# Oil, hazelnut                                        100.0            7.4
# Oil, fully hydrogenated, cottonseed, industrial      100.0           94.0
# Oil, babassu                                         100.0           81.0
# Oil, bearded seal (Oogruk) (Alaska Native)           100.0           11.0
# Oil, bowhead (Alaska Native), whale                  100.0            0.0
#
#                                                  monounsaturated_fatty_acids  \
# name
# Oil, hazelnut                                                         78.000
# Oil, fully hydrogenated, cottonseed, industrial                        1.529
# Oil, babassu                                                          11.400
# Oil, bearded seal (Oogruk) (Alaska Native)                            47.080
# Oil, bowhead (Alaska Native), whale                                    0.000
#
# ...
